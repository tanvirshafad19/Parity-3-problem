# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
import os
os.chdir('/content/drive/MyDrive/CPE520/HW#7')
# !pwd
# Out:
# /content
# /content/drive/MyDrive/CPE520/HW#7

# %%
run home_work_7-1.py

# %%
run home_work_7-2.py
